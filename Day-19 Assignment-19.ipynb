# %% [markdown]
# ## Day-19
# ## Assignment-19
# ## Exercise :

# %%
import openpyxl
path = "students.xlsx"
wb_obj = openpyxl.load_workbook(path)
sheet_obj = wb_obj.active
cell_obj = sheet_obj.cell(row = 2, column = 2)
print(cell_obj.value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-09782a2c5953> in <module>
# ----> 1 import openpyxl
#       2 path = "students.xlsx"
#       3 wb_obj = openpyxl.load_workbook(path)
#       4 sheet_obj = wb_obj.active
#       5 cell_obj = sheet_obj.cell(row = 2, column = 2)
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
#dbse = mydb.cursor()
#dbse.execute("CREATE DATABASE Students_Management_System1")
print("Students_Management_System Already Created")
# Out:
# Students_Management_System Already Created

# %%
dbse = mydb.cursor()
dbse.execute("SHOW DATABASES")
for entry in dbse:
print(entry)
# Out:
#   File "<ipython-input-13-80c4c148f084>", line 4
#     print(entry)
#         ^
# IndentationError: expected an indented block

# %%
mydb = mysql.connector.connect(
host="localhost",
user="root",
password="root",
database="students_management_system1"
)
dbse = mydb.cursor()
dbse.execute("CREATE TABLE studentdata(rno VARCHAR(10),name VARCHAR(255),department VAR)
CHAR(255) ,contact_no VARCHAR(255),sem1_marks VARCHAR(255),sem2_marks VARCHAR(255),averag
e VARCHAR(255))")
# Out:
#   File "<ipython-input-16-6df87800e63c>", line 8
#     dbse.execute("CREATE TABLE studentdata(rno VARCHAR(10),name VARCHAR(255),department VAR)
#                                                                                             ^
# SyntaxError: EOL while scanning string literal

# %%
mydb = mysql.connector.connect(
host="localhost",
user="root",
password="root",
database="students_management_system1"
)
dbse = mydb.cursor()
dbse.execute("SHOW TABLES")
for value in dbse:
    print(value)
# Out:
#   File "<ipython-input-17-ae201bc8fe1b>", line 10
#     print(value)
#         ^
# IndentationError: expected an indented block

# %%
mydb = mysql.connector.connect(
host="localhost",
user="root",
password="root",
database="students_management_system"
)
cur = mydb.cursor()
cur.execute('SELECT * FROM studentdata')
for row in cur:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9ba2194817fc> in <module>
# ----> 1 mydb = mysql.connector.connect(
#       2 host="localhost",
#       3 user="root",
#       4 password="root",
#       5 database="students_management_system"
#
# NameError: name 'mysql' is not defined

# %%
import xlrd
xl_sheet = xlrd.open_workbook("students.xlsx")
xl_sheet
sheet_name =xl_sheet.sheet_names()
sheet_name
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-4d64438180ad> in <module>
# ----> 1 import xlrd
#       2 xl_sheet = xlrd.open_workbook("students.xlsx")
#       3 xl_sheet
#       4 sheet_name =xl_sheet.sheet_names()
#       5 sheet_name
#
# ModuleNotFoundError: No module named 'xlrd'

# %%
mydb = mysql.connector.connect(
host="localhost",
user="root",
password="root",
database="students_management_system"
)
cur = mydb.cursor()
for s in range(0,1):
    sheet=xl_sheet.sheet_by_index(s)
    sql= "INSERT INTO studentdata(rno,name,department,contact_no,sem1_marks,sem2_marks,average) VALUES(%s,%s,%s,%s,%s,%s,%s)"
for r in range(1,sheet.nrows):
    rno =sheet.cell(r,0).value
    name =sheet.cell(r,1).value
    department =sheet.cell(r,2).value
    contact_no =sheet.cell(r,3).value
    sem1_marks=sheet.cell(r,4).value
    sem2_marks=sheet.cell(r,5).value
    average =sheet.cell(r,6).value
    values =(rno,name,department,contact_no,sem1_marks,sem2_marks,average)
cur.execute(sql,values)
mydb.commit()
mycursor = mydb.cursor()
mycursor.execute("SELECT * FROM studentdata")
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
mydb.commit()
mydb.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6b1f0d41ef6e> in <module>
# ----> 1 mydb = mysql.connector.connect(
#       2 host="localhost",
#       3 user="root",
#       4 password="root",
#       5 database="students_management_system"
#
# NameError: name 'mysql' is not defined
