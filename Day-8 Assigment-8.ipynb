# %% [markdown]
# ## Day-8

# %% [markdown]
# ## Assignment-8

# %% [markdown]
# ## Exercise :

# %% [raw]
# Write a Python script to merge two Python dictionaries

# %%
def merge(car,bike):
    return(car.update(bike))
car ={
    '1':"City",
    '2':"AUDI Q8",
    '3':"i20"}
bike={
    '4':"Pulsar",
    '5':"Himalayan",
    '6':"FZ"}
print(merge(car,bike))
print(car)
# Out:
# None
# {'1': 'City', '2': 'AUDI Q8', '3': 'i20', '4': 'Pulsar', '5': 'Himalayan', '6': 'FZ'}

# %% [raw]
# Write a program to sort the value from descending to ascending in list and
# convert it in to a set.

# %%
#Initialize array     
list1 = [15, 2, 80, 7, 11];     
temp = 0;    
     
#Displaying elements of original array    
print("Elements of original array: ");    
for i in range(0, len(list1)):    
    print(list1[i], end=" ");    
     
#Sort the array in ascending order    
for i in range(0, len(list1)):    
    for j in range(i+1, len(list1)):    
        if(list1[i] > list1[j]):    
            temp = list1[i];    
            list1[i] = list1[j];    
            list1[j] = temp;    
print();    
     
#Displaying elements of the array after sorting    
    
print("Elements of array sorted in ascending order: ");    
for i in range(0, len(list1)):   
    print(list1[i], end=" ");

print("Converting the list to set :",set(list1))
# Out:
# Elements of original array:
# 15 2 80 7 11
# Elements of array sorted in ascending order:
# 2 7 11 15 80 Converting the list to set : {2, 7, 11, 15, 80}

# %% [raw]
# Write a Python program to list number of items in a dictionary key and sort the
# list with the help of a function & without the function.

# %%
dict1={
    'C':"Harsha",
    'A':"B",
    'Z':"Reddy",
    'E':"Vardhan"
}
print("The original dictionary is : " ,dict1)
  
# Sort Dictionary key and values List
# Using dictionary comprehension + sorted()
res = {key : sorted(dict1[key]) for key in sorted(dict1)}
  
# printing result 
print("The sorted dictionary : " + str(res))
# Out:
# The original dictionary is :  {'C': 'Harsha', 'A': 'B', 'Z': 'Reddy', 'E': 'Vardhan'}
# The sorted dictionary : {'A': ['B'], 'C': ['H', 'a', 'a', 'h', 'r', 's'], 'E': ['V', 'a', 'a', 'd', 'h', 'n', 'r'], 'Z': ['R', 'd', 'd', 'e', 'y']}

# %%
dict1={
    'C':"Harsha",
    'A':"B",
    'Z':"Reddy",
    'E':"Vardhan"
}
print("Original List :",dict1)
sort=sorted(dict1)
print("Sorted List :",sort)
# Out:
# Original List : {'C': 'Harsha', 'A': 'B', 'Z': 'Reddy', 'E': 'Vardhan'}
# Sorted List : ['A', 'C', 'E', 'Z']

# %% [raw]
# Write a Python program to get a string from a given string (user input) and
# change the first occurrence of the word to a user specified input.

# %%
# declaring a string variable
str =input("Enter Your Data")
# declaring an empty string variable for storing modified string
modified_str = ''

# iterating over the string
for char in range(0, len(str)):
# checking if the character at char index is equivalent to 'a'
    if(str[char] == 'a'):
    # append $ to modified string
        modified_str += '$'
    else:
        # append original string character
        modified_str += str[char]

print("Modified string : ")
print(modified_str)
# Out:
# Enter Your Data Harsha
# Modified string :
# H$rsh$

# %% [raw]
# Write a Python program to get a string from a given string where all
# occurrences of its first char have been changed to capital letter.

# %%
# declaring a string variable
str1 =input("Enter Your Data")
def change_char(str1):
  char = str1[0]
  str1 = str1.replace(char, '')
  str1 = char + str1[1:]

  return str1

print(str.capitalize())
# Out:
# Enter Your Data harsha
# Harsha

# %% [raw]
# Write a Python program to find the repeated items of a list

# %%
#Finding the Repeated Values
l=[20,5,2,6,5,20,6,88]
l1=[]
for i in l:
    if i not in l1:
        l1.append(i)
    else:
        print(i,end= " ")
# Out:
# 5 20 6

# %% [raw]
# Write a Python program to check the sum of three elements and divided by a
# value which is given as an input by the user

# %%
a=int(input("Enter a value :"))
b=int(input("Enter b value :"))
c=int(input("Enter c value :"))
sum= a+b+c
div= (a+b+c)/c
print("sum of three elements :",sum)
print("divided by a value",div)
# Out:
# Enter a value : 10
# Enter b value : 20
# Enter c value : 5
# sum of three elements : 35
# divided by a value 7.0

# %% [raw]
# Write a Python program to find the Mean,median,mode among three given
# numbers

# %%
#importing the library
# Mean
import numpy
num=[3,5,7,9,11]
x=numpy.mean(num)
print("mean of the num is :",x)
# Out:
# mean of the num is : 7.0

# %%
#Median
import numpy
num=[3,5,7,9,11]
x=numpy.median(num)
print("median of the num is :",x)
# Out:
# median of the num is : 7.0

# %%
# Mode
from scipy import stats
num=[2,5,4,9,9,9,8,9]
x=stats.mode(num)
print("MOde of the Num is :",x)
# Out:
# MOde of the Num is : ModeResult(mode=array([9]), count=array([4]))

# %% [raw]
# Write a Python program to swap cases of a given string

# %%
#Swapping a and b
a=[3,5,7,9,11]
b=[1,6,5,8,9]
temp=0
print("Before Swapping is :",a,b)
for i in a,b :
    if a>b :
        temp=a;
        a=b;
        b=temp;
        print("After Swapping is :",a,b)
# Out:
# Before Swapping is : [3, 5, 7, 9, 11] [1, 6, 5, 8, 9]
# After Swapping is : [1, 6, 5, 8, 9] [3, 5, 7, 9, 11]

# %% [raw]
# Write a program to convert an integer to binary & octa decimal

# %%
a=10
b=5
print("integer into binary is:",bin(a))         #converting integer to binary
print("integer into octa decimal is :",oct(a))  #converting integer to octa decimal
# Out:
# integer into binary is: 0b1010
# integer into octa decimal is : 0o12
