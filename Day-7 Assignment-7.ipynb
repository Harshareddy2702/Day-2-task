# %% [markdown]
# ## Day-7

# %% [markdown]
# ## Functions

# %%
# A function is defined using the "def" keyword
def display(x):                                   # Here x is parameter
    print("Welcome to Day-7")
    print("Marks of Last Task",x)
display(10)                                       # calling function                      #10 is argument
# Out:
# Welcome to Day-7
# Marks of Last Task 10

# %%
def team(p):
    print("Name of the Player is :",p)
team("Dhoni")
team("KL Rahul")
# Out:
# Name of the Player is : Dhoni
# Name of the Player is : KL Rahul

# %%
def state(AP_cap,KA_cap,TN_cap):                 #Assigning multiple parameters to a function
    print("Captial of AP is :",AP_cap)
    print("Captial of KA is :",KA_cap)
    print("Captial of TN is :",TN_cap)
state("Hyderabad","Banglore","Chennai")         #Assigning multiple arguemnets to a function
# Out:
# Captial of AP is : Hyderabad
# Captial of KA is : Banglore
# Captial of TN is : Chennai

# %%
# * is used when we don't know how many arguments is passed
def ipl(*teams):
    print("Name of the Team is :",teams)
ipl("CSK","KXIP","MI","SRH","RR","RCB","KKR","DD")
# Out:
# Name of the Team is : ('CSK', 'KXIP', 'MI', 'SRH', 'RR', 'RCB', 'KKR', 'DD')

# %%
# we can assign the key and value in the argument
def player(player1,player2,player3):
    print("My Favorite Player is :", player1)
    print("My Best Player is :", player2)
    print("My Fantasy Player is", player3)
player(player1="Dhoni",player2="Rohit",player3="KL Rahul")
# Out:
# My Favorite Player is : Dhoni
# My Best Player is : Rohit
# My Fantasy Player is KL Rahul

# %%
def cricket(**player):
    print("products issued to the player :")
	
    for product, quantity in player.items():
        print(product,":",quantity)

print("PRODUCTS ISSUED TO DHONI")
product_summary(SHOES = 3, BATS = 4)

print("PRODUCTS ISSUED TO KLRAHUL")
product_summary(SHOES = 3, BATS = 2)
# Out:
# PRODUCTS ISSUED TO DHONI
# Products purchased:
# SHOES : 3
# BATS : 4
# PRODUCTS ISSUED TO KLRAHUL
# Products purchased:
# SHOES : 3
# BATS : 2

# %%
# return a value, use the return statement
def days(y):
    return y*10
print(days(3))
# Out:
# 30

# %%
# passing a default value while initiation
def myfunc(fname,lname="Reddy"):
    print("First Name :",fname)
    print("Last Name :",lname)
myfunc("Harsha")
# Out:
# First Name : Harsha
# Last Name : Reddy

# %% [markdown]
# ## Execise :

# %% [raw]
# Create a function getting two integer inputs from user. & print the following:
#
# Addition of two numbers is +value
#
# Subtraction of two numbers is +value
#
# Division of two numbers is +value
#
# Multiplication of two numbers is +value
#
# Here the value represents math function associated

# %%
a=int(input("Enter First Number :"))
b=int(input("Ebter Second Number :"))
def math_function(a,b):
    print("Addition of two numbers is :",(a + b))
    print("Subtraction of two numbers is :",(a - b))
    print("Division of two numbers is  :",(a/b))
    print("Multiplication of two numbers is :",(a*b))
math_function(a,b)
# Out:
# Enter First Number : 6
# Ebter Second Number : 2
# Addition of two numbers is : 8
# Subtraction of two numbers is : 4
# Division of two numbers is  : 3.0
# Multiplication of two numbers is : 12

# %% [raw]
# Create a function covid( ) & it should accept patient name, and body temperature, by default the body temperature should be 98 degree

# %%
def covid(patientname,bodytemperature= 98):
    print("please Enter Patient Name :",patientname)
    print("Body Temperature of Patient :",bodytemperature)
covid("Harsha")
# Out:
# please Enter Patient Name : Harsha
# Body Temperature of Patient : 98
