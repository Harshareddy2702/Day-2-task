# %% [markdown]
# ## Day-17
# ## Assignment-17
# ## Exercise :

# %% [raw]
# Create a connection for DB and print the version using a python program

# %%
import os
import mysql
import mysql.connector

mydb=mysql.connector.connect(host='Local Host',
                             database='database',
                             user='root',
                             password="Harsha0201"
                            )
print(mydb)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-9ef932b70f3c> in <module>
#       1 import os
# ----> 2 import mySQL
#       3 import mysql.connector
#       4
#       5 mydb=mysql.connector.connect(host='Local Host',
#
# ModuleNotFoundError: No module named 'mySQL'

# %% [raw]
# Create a multiple tables & insert data in table

# %%
# Create a employee table and read all the employee name in the table using for loop
import mysql.connector
mydb = mysql.connector.connect(
                               host="localhost",
                               database = "HarshaReddy",
                               user ="root",
                               password="Harsha0201"
)

dbse = mydb.cursor()
dbse.execute("CREATE TABLE Employee1 ( EMP_name VARCHAR(255), EMP_no int , EMP_city VARCHAR(255), EMPdep VARCHAR(255))")
dbse.execute("INSERT INTO Employee ( EMP_name, EMP_no, EMP_city, EMPdep) VALUES  ('Harsha',27,'HYD','BI')")
mydb.commit()

dbse.execute("SHOW TABLES")
for value in dbse:
    print(value)

dbse.execute("SELECT * FROM Employee")

for value in dbse:
    print(value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-0f3bd0974e07> in <module>
#       1 # Create a employee table and read all the employee name in the table using for loop
# ----> 2 import mysql.connector
#       3 mydb = mysql.connector.connect(
#       4                                host="localhost",
#       5                                database = "HarshaReddy",
#
# ModuleNotFoundError: No module named 'mysql'

# %% [raw]
# Create a employee table and read all the employee name in the table using for loop

# %%
import mysql.connector
mydb= mysql.connector.connect(host='Local host',
                              database='database',
                              user='root',
                              password='Harsha02041')

dbse=mydb.cursor()
dbse.excute("CREATE TABLE Employee (Emp_name HARSHA(27),Emp_no int,Emp_city HARSHA(27),Emp_dept HARSHA(27))")
dbse.excute("SHOW Tables")
for value in dbse:
    print(dbse)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-cc38818c63ac> in <module>
# ----> 1 import mysql.connector
#       2 mydb= mysql.connector.connect(host='Local host',
#       3                               database='database',
#       4                               user='root',
#       5                               password='Harsha02041')
#
# ModuleNotFoundError: No module named 'mysql'
