# %% [markdown]
# ## Day-9

# %% [markdown]
# ## Assignment-9

# %% [markdown]
# ## Exercise :

# %% [raw]
# Write a program to loop through a list of numbers and add +2 to every value to elements in list

# %%
list=[22,25,28,32,40]
for i,val in enumerate(list):
    print(i,':',val+2)
# Out:
# 0 : 24
# 1 : 27
# 2 : 30
# 3 : 34
# 4 : 42

# %% [raw]
# Write a program to get the below pattern
# 54321
# 4321
# 321
# 21
# 1

# %% [raw]
# Write a program to get the below pattern
# 54321
# 4321
# 321
# 21
# 1

# %%
for i in range(5,0,-1) :
    for j in range(i,0,-1):
        print(j,end="")
    print()
# Out:
# 54321
# 4321
# 321
# 21
# 1

# %% [raw]
# Python Program to Print the Fibonacci sequence

# %%
n = int(input("How many terms you want? "))  
# first two terms  
n1 = 4
n2 = 2  
count = 1  
# check if the number of terms is valid  
if n <= 0:  
    print("Plese enter a positive integer")  
elif n == 1:  
    print("Fibonacci sequence:")  
    print(n1)  
else:  
    print("Fibonacci sequence:")  
    print(n1,",",n2,end=', ')  
    while count < n:  
        nth = n1 + n2  
        print(nth,end=' , ')  
        # update values  
        n1 = n2  
        n2 = nth  
        count += 1
# Out:
# How many terms you want?  10
# Fibonacci sequence:
# 4 , 2, 6 , 8 , 14 , 22 , 36 , 58 , 94 , 152 , 246 ,

# %% [raw]
# Explain Armstrong number and write a code with a function

# %%
num=int(input("Enter a Number :"))
sum=0
temp=num
while temp>0 :
    digit=temp % 10
    sum+=digit**3
    temp//=10
if num==sum:
    print("It is an Armstrong")
else:
    print("It is not Armstrong")
# Out:
# Enter a Number : 151
# It is not Armstrong

# %% [raw]
# Write a program to print the multiplication table of 9

# %%
num=9
for i in range(1,15):
    print(num,'x',i,'=',i*num)
# Out:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
# 9 x 11 = 99
# 9 x 12 = 108
# 9 x 13 = 117
# 9 x 14 = 126

# %% [raw]
# Check if a program is negative or positive

# %%
num=int(input("Enter a positive or Negative Number :"))
if (num>0) :
    print("It is a Positive Number")
else :
    print("It is a Negative Number")
# Out:
# Enter a positive or Negative Number : 18
# It is a Positive Number

# %% [raw]
# Write a program to convert the number of days to ages

# %%
print("Enter the days::")

d= int(input())
y=None
w=None
# Conversion of days in to years, weeks and days
y = (int)(d / 365)
w = (int)((d % 365) / 7)
d = (int)(d - ((y * 365) + (w)))
a=y,w,d
print("Age is :",y, " Year, ", w, " Weeks, and ", d, " Days\n")
# Out:
# Enter the days::
#  455
# Age is : 1  Year,  12  Weeks, and  78  Days

# %% [raw]
# Solve Trigonometry problem using math function write a program to solve using math function

# %%
import math 
a=int(input("Enter a Value :"))
print("The value of the sine is :",end="")
print(math.sin(a))
print("The value of the cosine is :",end="")
print(math.cos(a))
print("The value of the tan is :",end="")
print(math.tan(a))
# Out:
# Enter a Value : 1
# The value of the sine is :0.8414709848078965
# The value of the cosine is :0.5403023058681398
# The value of the tan is :1.5574077246549023

# %% [raw]
# Create a calculator only on a code level by using if condition (Basic arithmetic calculation)

# %%
# Defining the operators like Addition,Substraction,Multiplication,Division
def add(a,b):
    return a+b
def sub(a,b):
    return a-b
def mul(a,b):
    return a*b
def div(a,b):
    return a/b
print("Select the operator :")
print("1.Addition \n 2.Substraction \n 3.Multiplication \n 4.Division")
choice=input("Select Your Choice (1/2/3/4 :")
num1=float(input("Enter First Number :"))
num2=float(input("Enter second Number :"))
if choice=='1':
    print("Addition of Two Number is :",num1,"+",num2,"=",add(num1,num2))
if choice=='2':
    print("Subtraction of Two Numbers is :",num1,"-",num2,"=",sub(num1,num2))
if choice=='3':
    print("Multiplication of Two Numbers is :",num1,"*",num2,"=",mul(num1,num2))
if choice=='4':
    print("Division of Two Numbers is :",num1,"/",num2,"=",div(num1,num2))
# Out:
# Select the operator :
# 1.Addition
#  2.Substraction
#  3.Multiplication
#  4.Division
# Select Your Choice (1/2/3/4 : 4
# Enter First Number : 2
# Enter second Number : 0.5
# Division of Two Numbers is : 2.0 / 0.5 = 4.0
