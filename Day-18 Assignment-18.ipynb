# %% [markdown]
# ## Day-18
# ## Assignmen-18
# ## Exercise :

# %% [raw]
# Create a DB with doctor and doctor ID & patients visited

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="BESTENLIST"
)
print(mydb)
dbse = mydb.cursor()

dbse.execute("CREATE DATABASE DOCTORS")
dbse = mydb.cursor()

dbse.execute("SHOW DATABASES")

for entry in dbse:
  print(entry)



dbse.execute("CREATE TABLE DOCTORS (dr_id VARCHAR(255), Patient_visited VARCHAR(255))")
dbse = mydb.cursor()

dbse.execute("SHOW TABLES")

for value in dbse:
  print(value)
('doctors',)
dbse = mydb.cursor()

sql = "INSERT INTO Doctors (dr_id , Patient_visited) VALUES (%s,%s)"
val = [
    ('Dr1','9'),
    ('Dr2','3'),
    ('Dr3','8'),
    ('Dr4','0'),
    ('Dr23','5'),
    ('Dr26','9'),
    ('Dr8','0'),
    ('Dr5','0'),
    ('Dr13','5'),
    ('Dr62','9'),
    ('Dr83','0')    
]

dbse.executemany(sql, val)

mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-4039ba4a6233> in <module>
# ----> 1 import mysql.connector
#       2 mydb = mysql.connector.connect(
#       3   host="localhost",
#       4   user="root",
#       5   password="BESTENLIST"
#
# ModuleNotFoundError: No module named 'mysql'

# %% [raw]
# Get the doctor(s) who have more than 5 patients visited

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Harsha27",
  database="DOCTOR"
)
dbse = mydb.cursor()
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM Doctors where Patient_visited >5")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-4c3e3c210c8c> in <module>
# ----> 1 import mysql.connector
#       2 mydb = mysql.connector.connect(
#       3   host="localhost",
#       4   user="root",
#       5   password="Harsha27",
#
# ModuleNotFoundError: No module named 'mysql'

# %% [raw]
# Get the doctors with no patients visit

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Harsha27",
  database="DOCTOR"
)
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM Doctors where Patient_visited=0")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-8602a7515c69> in <module>
# ----> 1 import mysql.connector
#       2 mydb = mysql.connector.connect(
#       3   host="localhost",
#       4   user="root",
#       5   password="Harsha27",
#
# ModuleNotFoundError: No module named 'mysql'
