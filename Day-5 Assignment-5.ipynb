# %% [markdown]
# ## Day 5 – User Inputs, Other Important Datatypes
# ## Python User Input :

# %% [raw]
# Example :

# %%
a=int(input("Enter Firs Number"))
b=int(input("Enter Second Number"))
sum=a+b
print(sum)
# Out:
# Enter Firs Number 25
# Enter Second Number 5
# 30

# %% [markdown]
# ## Python Lists :

# %%
# Building a list
L1=[10,20,30,50]
L2=['H','A','R','S','H','A']
print(L1)
print(L2)
# Out:
# [10, 20, 30, 50]
# ['H', 'A', 'R', 'S', 'H', 'A']

# %%
# Accessing a list
L1=['H','A','R','S','H','A']
print(L1)
print(L1[5])   #L[5] returns the item at index 5
print(L1[1:])  #L[1:] returns objects from 1 to the last object
print(L1[1:3]) #L[1:3] returns a new list, containing the objects between 1 and 3.
print(L1[-1])  #L1 access the last item in the list
print(L1[-4:-1]) #L[-4:-1] returns a new list, containing the objects between -4 and -1.
print(L1[-5:])   #L[-5:] returns objects from -5 to the last object
# Out:
# ['H', 'A', 'R', 'S', 'H', 'A']
# A
# ['A', 'R', 'S', 'H', 'A']
# ['A', 'R']
# A
# ['R', 'S', 'H']
# ['A', 'R', 'S', 'H', 'A']

# %%
L=['I','N','D','I','A','N']
L.append('S')               # Append add the value after the last item
print(L)
# Out:
# ['I', 'N', 'D', 'I', 'A', 'N', 'S']

# %%
L=['I','N','D','I','A','N']
L.extend('WELCOME')        #Extends adds sequence or lists  
print(L)
# Out:
# ['I', 'N', 'D', 'I', 'A', 'N', 'W', 'E', 'L', 'C', 'O', 'M', 'E']

# %%
L=['I','N','D','I','A','N']
L.insert(7,'1')          #Inserts an item at a given index and move remaining items to right 
print(L)
# Out:
# ['I', 'N', 'D', 'I', 'A', 'N', '1']

# %%
L=['I','N','D','I','A','N']
del L[5]                #Deletes the 5th Index item
print(L)
# Out:
# ['I', 'N', 'D', 'I', 'A']

# %%
L=['I','N','D','I','A','N']
del L[5:6]             #Deletes items between 5 to 6
print(L)
del L[3:6]             #Deletes items between 3 to 6
print(L)
# Out:
# ['I', 'N', 'D', 'I', 'A']
# ['I', 'N', 'D']

# %%
L=['I','N','D','I','A','N']
L.pop()               #Pops the last item
L.pop(4)              #pops the 4th index item in the list
L.remove('D')         #removes the item D from the list
print(L)
# Out:
# ['I', 'N', 'I']

# %%
L=[100,50,110,250,350]
print(min(L))
print(max(L))
print(sorted(L))
L.sort()
print(L)
# Out:
# 50
# 350
# [50, 100, 110, 250, 350]
# [50, 100, 110, 250, 350]

# %%
# Nested List
L=[1,2,["hello"],('hi')] 
print(L)
# Out:
# [1, 2, ['hello'], 'hi']

# %% [markdown]
# ## Python tuples :

# %%
T=(27,"Harsha",'B',8.6) #Tuple with mixed datatypes
print(T)
print(T[2])             #Accessing tuple elements using indexing
print(T[1:])
# Out:
# (27, 'Harsha', 'B', 8.6)
# B
# ('Harsha', 'B', 8.6)

# %% [markdown]
# ## Exercise :

# %% [raw]
# Write a program to create a list of n integer values and do the following
# Add an item in to the list (using function)
# Delete (using function)
# Store the largest number from the list to a variable
# Store the Smallest number from the list to a variable

# %%
# Write a program to create a list of n integer
leapyear =[2000,2004,2008,2012,2016]
print(leapyear)


# Add an item in to the list (using function)
leapyear.append(2020)
leapyear.insert(0,2000)
print(leapyear)


# Delete (using function)
del leapyear[0]
leapyear.remove(2000)
print(leapyear)
#Store the largest number from the list to a variable
largvar=max(leapyear)
print("The largest number from the list is :",largvar)
#Store the Smallest number from the list to a variable
smallvar= min(leapyear)
print("The smallest number from the list is :",smallvar)
# Out:
# [2000, 2004, 2008, 2012, 2016]
# [2000, 2000, 2004, 2008, 2012, 2016, 2020]
# [2004, 2008, 2012, 2016, 2020]
# The largest number from the list is : 2020
# The smallest number from the list is : 2004

# %% [markdown]
# ##  2) Create a tuple and print the reverse of the created tuple

# %%
my_tuple=(6,5,4,3,2,1-1)
print(my_tuple[::-1])
# Out:
# (0, 2, 3, 4, 5, 6)

# %%
my_tuple=('H','A','R','S','H','A')
print(my_tuple)
x = reversed(my_tuple)
print(tuple(x))
# Out:
# ('H', 'A', 'R', 'S', 'H', 'A')
# ('A', 'H', 'S', 'R', 'A', 'H')

# %% [markdown]
# ## 3) Create a tuple and convert tuple into list

# %%
my_tuple=('H','A','R','S','H','A')
print(my_tuple)
print(list(my_tuple))
# Out:
# ('H', 'A', 'R', 'S', 'H', 'A')
# ['H', 'A', 'R', 'S', 'H', 'A']

# %% [markdown]
#    ## Thank You
