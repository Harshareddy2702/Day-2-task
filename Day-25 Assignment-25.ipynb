# %% [markdown]
# ## Day-25
# ## Assignment-25
# ## Exercise :

# %% [raw]
# 1. Write a Python program to convert a string to datetime

# %%
import datetime
def convert(date_time):
    format = '%b %d %Y %I:%M%p' # The format
    datetime_str = datetime.datetime.strptime(date_time, format)
    return datetime_str
date_time='Feb 27 2001 4:30PM'
print(convert(date_time))
# Out:
# 2001-02-27 16:30:00

# %% [raw]
# 2. Write a Python program to subtract five days (last working day) from current date

# %%
from datetime import date, timedelta
abs=date.today() - timedelta(5)
print("Today date is :",date.today())
print("Five days before today's date is :",abs)
# Out:
# Today date is : 2021-07-11
# Five days before today's date is : 2021-07-06

# %% [raw]
# 3. Write a Python program to convert the date to datetime using a function

# %%
from datetime import datetime
a=date.today()
print(datetime.combine(a,datetime.min.time()))
# Out:
# 2021-07-11 00:00:00

# %% [raw]
# Write a Python program to print next 7 days (week) starting from today

# %%
import datetime
data = datetime.datetime.today()
for x in range(0,7):
    print(data + datetime.timedelta(days=x))
# Out:
# 2021-07-11 11:28:43.346532
# 2021-07-12 11:28:43.346532
# 2021-07-13 11:28:43.346532
# 2021-07-14 11:28:43.346532
# 2021-07-15 11:28:43.346532
# 2021-07-16 11:28:43.346532
# 2021-07-17 11:28:43.346532
