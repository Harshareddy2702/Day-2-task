# %% [markdown]
# ## Day-28

# %%
from threading import *
from time import *
from datetime import date,datetime

class thread(Thread):
    def run(self):
        print(datetime.today())
        sleep(0.2)

class thread1(Thread):
    def run(self):
        print(datetime.today())
        sleep(1)


a = thread()
a.start()
b=thread1()
b.start()
print("\nnumber of active threads : ",active_count())
# Out:
# 2021-07-14 13:16:30.858184
# 2021-07-14 13:16:30.859126
#
# number of active threads :  7
