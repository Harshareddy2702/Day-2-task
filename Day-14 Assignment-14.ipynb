# %% [markdown]
# ## Day-14
# ## Assignment-14
# ## Exercise :

# %% [raw]
# List down all the error types and check all the errors using a python program for all errors

# %%
L1=[2,5,7,9,11]
print(L1[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-24a2c03cf084> in <module>
#       1 L1=[2,5,7,9,11]
# ----> 2 print(L1[5])
#
# IndexError: list index out of range

# %%
dict={'car1':'I20','car2':'swift'}
print(dict['key1'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-ef737e9fe465> in <module>
#       1 dict={'car1':'I20','car2':'swift'}
# ----> 2 print(dict['key1'])
#
# KeyError: 'key1'

# %%
# Type error
print(5+'10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-7884b715c227> in <module>
#       1 # Type error
# ----> 2 print(5+'10')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Value Error
print(int("abcd"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4350bed8d6fb> in <module>
#       1 # Value Error
# ----> 2 print(int("abcd"))
#
# ValueError: invalid literal for int() with base 10: 'abcd'

# %%
#Nameerror
print(harsha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2ea81a04c171> in <module>
#       1 #Nameerror
# ----> 2 print(harsha)
#
# NameError: name 'harsha' is not defined

# %% [raw]
# Design a simple calculator app with try and except for all use cases

# %%
def addition(a, b):
    try:
        result = a + b
        print("Addition is : ",result)
    except Exception as e:
        print(e)

def subtraction(a, b):
    try:
        result = a - b
        print("subtraction is : ",result)
    except Exception as e:
        print(e)

def multiplication(a, b):
    try:
        result = a * b
        print("multiplication is : ",result)
    except Exception as e:
        print(e)
        
def division(a, b):
    try:
        result = a / b
        print("division is : ",result)
    except Exception as e:
        print(e)


def calculation():
    try:
        a = int(input("enter first number : "))
        b = int(input("enter second number : "))
        addition(a, b)
        subtraction(a, b)
        multiplication(a, b)
        division(a, b)
        
    except Exception as e:
        print("Only Integers Allowed")
        calculation()
#call a function
calculation()
# Out:
# enter first number :  25
# enter second number :  35
# Addition is :  60
# subtraction is :  -10
# multiplication is :  875
# division is :  0.7142857142857143

# %% [raw]
# print one message if the try block raises a NameError and another for other errors

# %%
try :
    print(a)
except NameError :
    print("a is not defined")
except :
    print("Refresh")
# Out:
# a is not defined

# %% [raw]
# When try-except scenario is not required?

# %% [raw]
# when trying to get input inside the trycatch block

# %% [raw]
# Try getting an input inside the try catch block

# %%
try :
    a=input("Enter Your Details : ")
except :
    print("Enter Your Data in Any Type ")
finally :
    print("Try And Exception are finished")
# Out:
# Enter Your Details :  Harsha27
# Try And Exception are finished
